# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_path = "/root/data/"

df_fake = pd.read_csv(data_path + "Fake.csv")
df_true = pd.read_csv(data_path + "True.csv")
df_fake['label'] = 1  # Fake news label
df_true['label'] = 0   # Real news label
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      1
# 1  December 31, 2017      1
# 2  December 30, 2017      1
# 3  December 29, 2017      1
# 4  December 25, 2017      1

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       0
# 1  December 29, 2017       0
# 2  December 31, 2017       0
# 3  December 30, 2017       0
# 4  December 29, 2017       0

# %%
df = pd.concat([df_true,df_fake])
df = df.drop(['title','subject','date'],axis=1)
df.head()
# Out:
#                                                 text  label
# 0  WASHINGTON (Reuters) - The head of a conservat...      0
# 1  WASHINGTON (Reuters) - Transgender people will...      0
# 2  WASHINGTON (Reuters) - The special counsel inv...      0
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      0
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      0

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def load_glove_vectors(glove_file_path):
    word_vectors = {}
    with open(glove_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.strip().split()
            word = values[0]
            vector = np.array(values[1:], dtype='float32')
            word_vectors[word] = vector
    return word_vectors

def preprocess_text(text):
    text = text.lower()                              # Convert text to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text)          # Remove special characters and numbers
    tokens = word_tokenize(text)                     # Tokenization
    stop_words = set(stopwords.words('english'))     # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    
    # lemmatizer = WordNetLemmatizer()                 # Lemmatization  ex: running => run (not nesscessary, but i want to test)
    # tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return tokens

glove_path = "/root/data/glove/"
word_vectors = load_glove_vectors(glove_path + "glove.6B.100d.txt")


df['clean_text'] = df['text'].apply(preprocess_text)
df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                 text  label  \
# 0  WASHINGTON (Reuters) - The head of a conservat...      0
# 1  WASHINGTON (Reuters) - Transgender people will...      0
# 2  WASHINGTON (Reuters) - The special counsel inv...      0
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      0
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      0
#
#                                           clean_text
# 0  [washington, reuters, head, conservative, repu...
# 1  [washington, reuters, transgender, people, all...
# 2  [washington, reuters, special, counsel, invest...
# 3  [washington, reuters, trump, campaign, adviser...
# 4  [seattlewashington, reuters, president, donald...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

def tokens_to_vectors(tokens):
    vectors = []
    for token in tokens:
        if token in word_vectors:
            vectors.append(word_vectors[token])
    if not vectors: # return none if no valid word vectors found 
        return None
    return np.mean(vectors, axis=0)

df['doc_vector'] = df['clean_text'].apply(tokens_to_vectors)
df = df.dropna()

X_train = df['doc_vector'].tolist()
y_train = df['label']

df_2nd = pd.read_csv(data_path +"2nd/" +"train.csv")
df_2nd = df_2nd.drop(['title','author','id'],axis=1)

df_2nd['text'] = df_2nd['text'].astype(str)
df_2nd['clean_text'] = df_2nd['text'].apply(preprocess_text)
df_2nd['doc_vector'] = df_2nd['clean_text'].apply(tokens_to_vectors)
df_2nd = df_2nd.dropna()

X_test = df_2nd['doc_vector'].to_list()
y_test = df_2nd['label']

X_train = np.asarray(X_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report



knn_classifier = KNeighborsClassifier(n_neighbors=10)  
knn_classifier.fit(X_train, y_train)

knn_y_pred = knn_classifier.predict(X_test)


knn_accuracy = accuracy_score(y_test, knn_y_pred)
print("Accuracy:", knn_accuracy)
print('----------------')
print('Confusion matrix')
print(confusion_matrix(knn_y_pred,y_test))
print('----------------')
print('Classification report')
print(classification_report(knn_y_pred,y_test))
# Out:
# Accuracy: 0.5859397695361673
# ----------------
# Confusion matrix
# [[3544 1710]
#  [6842 8558]]
# ----------------
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.34      0.67      0.45      5254
#            1       0.83      0.56      0.67     15400
#
#     accuracy                           0.59     20654
#    macro avg       0.59      0.62      0.56     20654
# weighted avg       0.71      0.59      0.61     20654

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report



rf_classifier = RandomForestClassifier(n_estimators=100)  
rf_classifier.fit(X_train, y_train)

rf_y_pred = rf_classifier.predict(X_test)


rf_accuracy = accuracy_score(y_test, rf_y_pred)
print("Accuracy:", rf_accuracy)
print('----------------')
print('Confusion matrix')
print(confusion_matrix(rf_y_pred,y_test))
print('----------------')
print('Classification report')
print(classification_report(rf_y_pred,y_test))
# Out:
# Accuracy: 0.5674929795681224
# ----------------
# Confusion matrix
# [[3058 1605]
#  [7328 8663]]
# ----------------
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.29      0.66      0.41      4663
#            1       0.84      0.54      0.66     15991
#
#     accuracy                           0.57     20654
#    macro avg       0.57      0.60      0.53     20654
# weighted avg       0.72      0.57      0.60     20654

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

height = 100
width = 1
channels = 1

X_train = np.array(X_train)
X_test = np.array(X_test)

X_train = np.squeeze(X_train)
X_test = np.squeeze(X_test)


print(X_train.shape)



model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(100, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  


model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()


history = model.fit(X_train, y_train, epochs=50, batch_size=128, validation_split=0.1)
loss, accuracy = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 2024-05-28 08:27:23.530206: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-28 08:27:23.549298: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (44179, 100)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 98, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 49, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       401,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 401,921 (1.53 MB)
#  Trainable params: 401,921 (1.53 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8776 - loss: 0.2980 - val_accuracy: 0.8705 - val_loss: 0.2956
# Epoch 2/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9295 - loss: 0.1817 - val_accuracy: 0.9305 - val_loss: 0.1665
# Epoch 3/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9345 - loss: 0.1725 - val_accuracy: 0.9110 - val_loss: 0.2143
# Epoch 4/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9436 - loss: 0.1510 - val_accuracy: 0.9536 - val_loss: 0.1232
# Epoch 5/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9434 - loss: 0.1517 - val_accuracy: 0.9387 - val_loss: 0.1576
# Epoch 6/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9467 - loss: 0.1444 - val_accuracy: 0.9608 - val_loss: 0.1081
# Epoch 7/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9461 - loss: 0.1450 - val_accuracy: 0.8723 - val_loss: 0.3215
# Epoch 8/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9470 - loss: 0.1394 - val_accuracy: 0.9024 - val_loss: 0.2492
# Epoch 9/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9480 - loss: 0.1386 - val_accuracy: 0.8959 - val_loss: 0.2599
# Epoch 10/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9509 - loss: 0.1324 - val_accuracy: 0.9380 - val_loss: 0.1694
# Epoch 11/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9507 - loss: 0.1283 - val_accuracy: 0.9387 - val_loss: 0.1649
# Epoch 12/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9508 - loss: 0.1275 - val_accuracy: 0.9183 - val_loss: 0.2111
# Epoch 13/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9532 - loss: 0.1240 - val_accuracy: 0.9559 - val_loss: 0.1225
# Epoch 14/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9533 - loss: 0.1270 - val_accuracy: 0.8812 - val_loss: 0.3039
# Epoch 15/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9535 - loss: 0.1244 - val_accuracy: 0.9568 - val_loss: 0.1200
# Epoch 16/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9565 - loss: 0.1194 - val_accuracy: 0.9278 - val_loss: 0.1950
# Epoch 17/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9557 - loss: 0.1190 - val_accuracy: 0.8898 - val_loss: 0.2752
# Epoch 18/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9568 - loss: 0.1155 - val_accuracy: 0.9572 - val_loss: 0.1188
# Epoch 19/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9563 - loss: 0.1173 - val_accuracy: 0.9373 - val_loss: 0.1650
# Epoch 20/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9531 - loss: 0.1220 - val_accuracy: 0.9457 - val_loss: 0.1456
# Epoch 21/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9583 - loss: 0.1110 - val_accuracy: 0.9452 - val_loss: 0.1529
# Epoch 22/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9578 - loss: 0.1087 - val_accuracy: 0.9106 - val_loss: 0.2268
# Epoch 23/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9583 - loss: 0.1104 - val_accuracy: 0.9477 - val_loss: 0.1420
# Epoch 24/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9598 - loss: 0.1097 - val_accuracy: 0.9561 - val_loss: 0.1233
# Epoch 25/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9620 - loss: 0.1033 - val_accuracy: 0.8997 - val_loss: 0.2471
# Epoch 26/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9616 - loss: 0.1026 - val_accuracy: 0.8950 - val_loss: 0.2607
# Epoch 27/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9618 - loss: 0.1025 - val_accuracy: 0.9436 - val_loss: 0.1549
# Epoch 28/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9668 - loss: 0.0927 - val_accuracy: 0.9271 - val_loss: 0.1889
# Epoch 29/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9631 - loss: 0.1001 - val_accuracy: 0.9095 - val_loss: 0.2249
# Epoch 30/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9638 - loss: 0.0992 - val_accuracy: 0.9296 - val_loss: 0.1873
# Epoch 31/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9659 - loss: 0.0950 - val_accuracy: 0.9500 - val_loss: 0.1331
# Epoch 32/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9691 - loss: 0.0851 - val_accuracy: 0.9036 - val_loss: 0.2382
# Epoch 33/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9677 - loss: 0.0880 - val_accuracy: 0.9443 - val_loss: 0.1554
# Epoch 34/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9673 - loss: 0.0901 - val_accuracy: 0.9319 - val_loss: 0.1847
# Epoch 35/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9680 - loss: 0.0868 - val_accuracy: 0.9031 - val_loss: 0.2504
# Epoch 36/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9674 - loss: 0.0862 - val_accuracy: 0.9633 - val_loss: 0.1058
# Epoch 37/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9682 - loss: 0.0849 - val_accuracy: 0.9439 - val_loss: 0.1485
# Epoch 38/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9704 - loss: 0.0804 - val_accuracy: 0.9740 - val_loss: 0.0724
# Epoch 39/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9701 - loss: 0.0824 - val_accuracy: 0.9303 - val_loss: 0.1895
# Epoch 40/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9705 - loss: 0.0805 - val_accuracy: 0.9672 - val_loss: 0.0937
# Epoch 41/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9686 - loss: 0.0826 - val_accuracy: 0.9597 - val_loss: 0.1135
# Epoch 42/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9739 - loss: 0.0756 - val_accuracy: 0.9402 - val_loss: 0.1554
# Epoch 43/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9717 - loss: 0.0784 - val_accuracy: 0.9262 - val_loss: 0.1928
# Epoch 44/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9697 - loss: 0.0818 - val_accuracy: 0.9402 - val_loss: 0.1579
# Epoch 45/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9750 - loss: 0.0713 - val_accuracy: 0.9210 - val_loss: 0.2070
# Epoch 46/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9738 - loss: 0.0727 - val_accuracy: 0.9606 - val_loss: 0.1120
# Epoch 47/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9745 - loss: 0.0701 - val_accuracy: 0.9321 - val_loss: 0.1866
# Epoch 48/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9722 - loss: 0.0777 - val_accuracy: 0.9556 - val_loss: 0.1258
# Epoch 49/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9742 - loss: 0.0710 - val_accuracy: 0.9330 - val_loss: 0.1795
# Epoch 50/50
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9765 - loss: 0.0676 - val_accuracy: 0.9599 - val_loss: 0.1167
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - accuracy: 0.5869 - loss: 1.9860
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# Test Loss: 1.966870903968811
# Test Accuracy: 0.588263750076294

# %%
y_pred_cnn = np.round(y_pred).flatten()
cnn_accuracy = accuracy_score(y_test, y_pred_cnn)
print('----------------')
print('Confusion matrix')
print(confusion_matrix(y_test, y_pred_cnn))
print('----------------')
print('Classification report')
print(classification_report(y_test, y_pred_cnn))
# Out:
# ----------------
# Confusion matrix
# [[3256 7130]
#  [1374 8894]]
# ----------------
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.70      0.31      0.43     10386
#            1       0.56      0.87      0.68     10268
#
#     accuracy                           0.59     20654
#    macro avg       0.63      0.59      0.56     20654
# weighted avg       0.63      0.59      0.55     20654
