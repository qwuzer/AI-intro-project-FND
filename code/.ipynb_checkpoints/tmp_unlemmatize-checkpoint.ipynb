# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_path = "/root/data/"

df_fake = pd.read_csv(data_path + "Fake.csv")
df_true = pd.read_csv(data_path + "True.csv")
df_fake['label'] = 1  # Fake news label
df_true['label'] = 0   # Real news label
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      1
# 1  December 31, 2017      1
# 2  December 30, 2017      1
# 3  December 29, 2017      1
# 4  December 25, 2017      1

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       0
# 1  December 29, 2017       0
# 2  December 31, 2017       0
# 3  December 30, 2017       0
# 4  December 29, 2017       0

# %%
df = pd.concat([df_true,df_fake])
df = df.drop(['title','subject','date'],axis=1)
df.head()
# Out:
#                                                 text  label
# 0  WASHINGTON (Reuters) - The head of a conservat...      0
# 1  WASHINGTON (Reuters) - Transgender people will...      0
# 2  WASHINGTON (Reuters) - The special counsel inv...      0
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      0
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      0

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def load_glove_vectors(glove_file_path):
    word_vectors = {}
    with open(glove_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.strip().split()
            word = values[0]
            vector = np.array(values[1:], dtype='float32')
            word_vectors[word] = vector
    return word_vectors

def preprocess_text(text):
    text = text.lower()                              # Convert text to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text)          # Remove special characters and numbers
    tokens = word_tokenize(text)                     # Tokenization
    stop_words = set(stopwords.words('english'))     # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    
    # lemmatizer = WordNetLemmatizer()                 # Lemmatization  ex: running => run (not nesscessary, but i want to test)
    # tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return tokens

glove_path = "/root/data/glove/"
word_vectors = load_glove_vectors(glove_path + "glove.6B.100d.txt")


df['clean_text'] = df['text'].apply(preprocess_text)
df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                 text  label  \
# 0  WASHINGTON (Reuters) - The head of a conservat...      0
# 1  WASHINGTON (Reuters) - Transgender people will...      0
# 2  WASHINGTON (Reuters) - The special counsel inv...      0
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      0
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      0
#
#                                           clean_text
# 0  [washington, reuters, head, conservative, repu...
# 1  [washington, reuters, transgender, people, all...
# 2  [washington, reuters, special, counsel, invest...
# 3  [washington, reuters, trump, campaign, adviser...
# 4  [seattlewashington, reuters, president, donald...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

def tokens_to_vectors(tokens):
    vectors = []
    for token in tokens:
        if token in word_vectors:
            vectors.append(word_vectors[token])
    if not vectors: # return none if no valid word vectors found 
        return None
    return np.mean(vectors, axis=0)

df['doc_vector'] = df['clean_text'].apply(tokens_to_vectors)
df = df.dropna()

X_train, X_test, y_train, y_test = train_test_split(df['doc_vector'].tolist(), df['label'], test_size=0.2, random_state=42)
df.head()
# Out:
#                                                 text  label  \
# 0  WASHINGTON (Reuters) - The head of a conservat...      0
# 1  WASHINGTON (Reuters) - Transgender people will...      0
# 2  WASHINGTON (Reuters) - The special counsel inv...      0
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      0
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      0
#
#                                           clean_text  \
# 0  [washington, reuters, head, conservative, repu...
# 1  [washington, reuters, transgender, people, all...
# 2  [washington, reuters, special, counsel, invest...
# 3  [washington, reuters, trump, campaign, adviser...
# 4  [seattlewashington, reuters, president, donald...
#
#                                           doc_vector
# 0  [-0.077617005, 0.18136153, 0.26305065, -0.2329...
# 1  [0.06912143, -0.054227337, 0.12197351, -0.0733...
# 2  [-0.096503265, -0.047262732, 0.27596813, -0.22...
#         1.16067961e-01,  6.71276033e-01, -1.29800737e-01, -1.78318191e+00,
#         1.67741701e-02, -1.58135369e-02,  1.02629721e+00,  2.37912118e-01,
#        -1.35355636e-01,  5.97490609e-01, -2.62507468e-01, -1.23041824e-01,
#         4.53904778e-01,  6.95752427e-02,  2.70540029e-01,  2.89437771e-01,
#         1.35701537e-01, -1.52366444e-01,  4.07812633e-02, -1.41648427e-01,
#        -2.78866708e-01, -2.62337625e-01, -7.93128684e-02,  1.05736122e-01,
#        -2.77329944e-02, -8.83345376e-04, -6.47174299e-01, -5.49538024e-02,
#         3.77977759e-01, -1.42242357e-01, -1.90641060e-01,  5.22668920e-02,
#        -9.12082732e-01, -2.05009103e-01, -1.16796799e-01, -7.56638274e-02,
#        -1.32118598e-01, -3.27226847e-01,  2.47706696e-02, -1.68582853e-02,
#         2.48580482e-02,  2.11328771e-02, -4.62640017e-01, -4.28925864e-02,
#        -1.34068310e-01, -1.15605824e-01,  2.28596911e-01,  1.15021981e-01],
#       dtype=float32)]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report



knn_classifier = KNeighborsClassifier(n_neighbors=10)  
knn_classifier.fit(X_train, y_train)

y_pred = knn_classifier.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print('----------------')
print('Confusion matrix')
print(confusion_matrix(y_pred,y_test))
print('----------------')
print('Classification report')
print(classification_report(y_pred,y_test))
# Out:
# Accuracy: 0.9215708465368945
# ----------------
# Confusion matrix
# [[4135  531]
#  [ 162 4008]]
# ----------------
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92      4666
#            1       0.88      0.96      0.92      4170
#
#     accuracy                           0.92      8836
#    macro avg       0.92      0.92      0.92      8836
# weighted avg       0.92      0.92      0.92      8836

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

height = 100
width = 1
channels = 1

X_train = np.array(X_train)
X_test = np.array(X_test)

X_train = np.squeeze(X_train)
X_test = np.squeeze(X_test)


print(X_train.shape)



model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(100, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  


model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()


history = model.fit(X_train, y_train, epochs=50, batch_size=128, validation_split=0.1)
loss, accuracy = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# (35343, 100)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 98, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 49, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │       401,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 401,921 (1.53 MB)
#  Trainable params: 401,921 (1.53 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 136/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8579 - loss: 0.3632
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8758 - loss: 0.3153 - val_accuracy: 0.9262 - val_loss: 0.1918
# Epoch 2/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9246 - loss: 0.1915 - val_accuracy: 0.9287 - val_loss: 0.1875
# Epoch 3/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9325 - loss: 0.1744 - val_accuracy: 0.9395 - val_loss: 0.1593
# Epoch 4/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9359 - loss: 0.1651 - val_accuracy: 0.9429 - val_loss: 0.1519
# Epoch 5/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9425 - loss: 0.1545 - val_accuracy: 0.9460 - val_loss: 0.1458
# Epoch 6/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9409 - loss: 0.1546 - val_accuracy: 0.9448 - val_loss: 0.1471
# Epoch 7/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9402 - loss: 0.1566 - val_accuracy: 0.9482 - val_loss: 0.1416
# Epoch 8/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9430 - loss: 0.1457 - val_accuracy: 0.9494 - val_loss: 0.1396
# Epoch 9/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9461 - loss: 0.1411 - val_accuracy: 0.9194 - val_loss: 0.2084
# Epoch 10/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9440 - loss: 0.1437 - val_accuracy: 0.9499 - val_loss: 0.1329
# Epoch 11/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9464 - loss: 0.1358 - val_accuracy: 0.9533 - val_loss: 0.1281
# Epoch 12/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9471 - loss: 0
50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9735 - loss: 0.0718 - val_accuracy: 0.9618 - val_loss: 0.1116
# Epoch 46/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9757 - loss: 0.0674 - val_accuracy: 0.9581 - val_loss: 0.1149
# Epoch 47/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9751 - loss: 0.0699 - val_accuracy: 0.9576 - val_loss: 0.1110
# Epoch 48/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9772 - loss: 0.0649 - val_accuracy: 0.9658 - val_loss: 0.0986
# Epoch 49/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9756 - loss: 0.0672 - val_accuracy: 0.9562 - val_loss: 0.1294
# Epoch 50/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.0653 - val_accuracy: 0.9629 - val_loss: 0.1053
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.9651 - loss: 0.0997
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# Test Loss: 0.10143157094717026
# Test Accuracy: 0.9634450078010559

# %%
y_pred_binary = np.round(y_pred).flatten()
print('----------------')
print('Confusion matrix')
print(confusion_matrix(y_test, y_pred_binary))
print('----------------')
print('Classification report')
print(classification_report(y_test, y_pred_binary))
# Out:
# ----------------
# Confusion matrix
# [[4181  116]
#  [ 207 4332]]
# ----------------
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      4297
#            1       0.97      0.95      0.96      4539
#
#     accuracy                           0.96      8836
#    macro avg       0.96      0.96      0.96      8836
# weighted avg       0.96      0.96      0.96      8836

# %%
df_2nd = pd.read_csv(data_path +"2nd/" +"train.csv")
df_2nd = df_2nd.drop(['title','author','id'],axis=1)
df_2nd.head()
# Out:
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
df_2nd['text'] = df_2nd['text'].astype(str)
df_2nd['clean_text'] = df_2nd['text'].apply(preprocess_text)
df_2nd['doc_vector'] = df_2nd['clean_text'].apply(tokens_to_vectors)
df_2nd = df_2nd.dropna()
df_2nd.head()
# Out:
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                           clean_text  \
# 0  [house, dem, aide, didnt, even, see, comeys, l...
# 1  [ever, get, feeling, life, circles, roundabout...
# 2  [truth, might, get, fired, october, tension, i...
# 3  [videos, civilians, killed, single, us, airstr...
# 4  [print, iranian, woman, sentenced, six, years,...
#
#                                           doc_vector
# 0  [-0.050807018, 0.04975615, 0.2658656, -0.32393...
# 1  [-0.0006217707, 0.215978, 0.294425, -0.0798217...
# 2  [-0.041612357, 0.21105361, 0.30817404, -0.0764...
# 3  [-0.1113405, 0.11081573, 0.092530034, -0.14825...
# 4  [0.19707523, 0.09317374, 0.060490813, -0.18551...

# %%
X_test = df_2nd['doc_vector'].to_list() 
y_test = df_2nd['label']

X_test = np.asarray(X_test).astype(np.float32)

loss, accuracy = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 149/646 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.6012 - loss: 2.0298
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - accuracy: 0.6001 - loss: 2.0123
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# Test Loss: 1.9965863227844238
# Test Accuracy: 0.5989638566970825

# %%
y_pred_binary = np.round(y_pred).flatten()
print('----------------')
print('Confusion matrix')
print(confusion_matrix(y_test, y_pred_binary))
print('----------------')
print('Classification report')
print(classification_report(y_test, y_pred_binary))
# Out:
# ----------------
# Confusion matrix
# [[3565 6821]
#  [1462 8806]]
# ----------------
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.71      0.34      0.46     10386
#            1       0.56      0.86      0.68     10268
#
#     accuracy                           0.60     20654
#    macro avg       0.64      0.60      0.57     20654
# weighted avg       0.64      0.60      0.57     20654

# %%
X_train, X_test, y_train, y_test = train_test_split(df_2nd['doc_vector'].to_list() , df_2nd['label'], test_size=0.2, random_state=42)

X_train = np.asarray(X_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)

history2 = model.fit(X_train, y_train, epochs=50, batch_size=128, validation_split=0.1)
loss, accuracy = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7151 - loss: 0.7146 - val_accuracy: 0.7925 - val_loss: 0.4445
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8039 - loss: 0.4261 - val_accuracy: 0.8234 - val_loss: 0.3847
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8279 - loss: 0.3875 - val_accuracy: 0.8318 - val_loss: 0.3783
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8336 - loss: 0.3723 - val_accuracy: 0.8409 - val_loss: 0.3657
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8472 - loss: 0.3545 - val_accuracy: 0.8397 - val_loss: 0.3557
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8497 - loss: 0.3490 - val_accuracy: 0.8548 - val_loss: 0.3391
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8560 - loss: 0.3361 - val_accuracy: 0.8572 - val_loss: 0.3372
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8552 - loss: 0.3311 - val_accuracy: 0.8645 - val_loss: 0.3278
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8617 - loss: 0.3219 - val_accuracy: 0.8639 - val_loss: 0.3391
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8581 - loss: 0.3282 - val_accuracy: 0.8651 - val_loss: 0.3342
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8603 - loss: 0.3190 - val_accuracy: 0.8645 - val_loss: 0.3261
# Epoch 12/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8656 - loss: 0.3078 - val_accuracy: 0.8657 - val_loss: 0.3151
# Epoch 13/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8714 - loss: 0.3038 - val_accuracy: 0.8754 - val_loss: 0.3112
# Epoch 14/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8665 - loss: 0.3047 - val_accuracy: 0.8536 - val_loss: 0.3260
# Epoch 15/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8735 - loss: 0.2959 - val_accuracy: 0.8675 - val_loss: 0.3129
# Epoch 16/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2799 - val_accuracy: 0.8657 - val_loss: 0.3103
# Epoch 17/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8798 - loss: 0.2835 - val_accuracy: 0.8669 - val_loss: 0.3135
# Epoch 18/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8783 - loss: 0.2843 - val_accuracy: 0.8705 - val_loss: 0.3139
# Epoch 19/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8812 - loss: 0.2806 - val_accuracy: 0.8663 - val_loss: 0.3071
# Epoch 20/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8819 - loss: 0.2751 - val_accuracy: 0.8687 - val_loss: 0.3065
# Epoch 21/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8840 - loss: 0.2684 - val_accuracy: 0.8687 - val_loss: 0.3104
# Epoch 22/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8826 - loss: 0.2719 - val_accuracy: 0.8657 - val_loss: 0.3088
# Epoch 23/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8861 - loss: 0.2693 - val_accuracy: 0.8584 - val_loss: 0.3452
# Epoch 24/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8846 - loss: 0.2753 - val_accuracy: 0.8705 - val_loss: 0.3011
# Epoch 25/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8875 - loss: 0.2654 - val_accuracy: 0.8730 - val_loss: 0.2993
# Epoch 26/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8889 - loss: 0.2599 - val_accuracy: 0.8663 - val_loss: 0.3122
# Epoch 27/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8937 - loss: 0.2546 - val_accuracy: 0.8730 - val_loss: 0.3074
# Epoch 28/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8934 - loss: 0.2511 - val_accuracy: 0.8730 - val_loss: 0.2970
# Epoch 29/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8939 - loss: 0.2542 - val_accuracy: 0.8675 - val_loss: 0.3053
# Epoch 30/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8938 - loss: 0.2497 - val_accuracy: 0.8669 - val_loss: 0.3049
# Epoch 31/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8942 - loss: 0.2459 - val_accuracy: 0.8717 - val_loss: 0.3021
# Epoch 32/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8929 - loss: 0.2506 - val_accuracy: 0.8663 - val_loss: 0.3131
# Epoch 33/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8944 - loss: 0.2479 - val_accuracy: 0.8657 - val_loss: 0.3115
# Epoch 34/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8980 - loss: 0.2401 - val_accuracy: 0.8657 - val_loss: 0.3173
# Epoch 35/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8998 - loss: 0.2350 - val_accuracy: 0.8627 - val_loss: 0.3149
# Epoch 36/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8936 - loss: 0.2493 - val_accuracy: 0.8748 - val_loss: 0.3062
# Epoch 37/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9001 - loss: 0.2283 - val_accuracy: 0.8754 - val_loss: 0.3027
# Epoch 38/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9016 - loss: 0.2272 - val_accuracy: 0.8669 - val_loss: 0.3038
# Epoch 39/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9068 - loss: 0.2176 - val_accuracy: 0.8760 - val_loss: 0.3005
# Epoch 40/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9058 - loss: 0.2278 - val_accuracy: 0.8730 - val_loss: 0.3155
# Epoch 41/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9046 - loss: 0.2283 - val_accuracy: 0.8766 - val_loss: 0.3019
# Epoch 42/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9048 - loss: 0.2269 - val_accuracy: 0.8693 - val_loss: 0.2996
# Epoch 43/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9076 - loss: 0.2185 - val_accuracy: 0.8766 - val_loss: 0.3000
# Epoch 44/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9121 - loss: 0.2089 - val_accuracy: 0.8730 - val_loss: 0.3046
# Epoch 45/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9085 - loss: 0.2164 - val_accuracy: 0.8730 - val_loss: 0.3078
# Epoch 46/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9096 - loss: 0.2113 - val_accuracy: 0.8596 - val_loss: 0.3297
# Epoch 47/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9078 - loss: 0.2096 - val_accuracy: 0.8754 - val_loss: 0.3041
# Epoch 48/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9107 - loss: 0.2091 - val_accuracy: 0.8699 - val_loss: 0.3048
# Epoch 49/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9120 - loss: 0.2088 - val_accuracy: 0.8633 - val_loss: 0.3302
# Epoch 50/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2060 - val_accuracy: 0.8748 - val_loss: 0.3006
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - accuracy: 0.8793 - loss: 0.2973
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# Test Loss: 0.3058738708496094
# Test Accuracy: 0.8784797787666321

# %%
y_pred_binary = np.round(y_pred).flatten()
print('----------------')
print('Confusion matrix')
print(confusion_matrix(y_test, y_pred_binary))
print('----------------')
print('Classification report')
print(classification_report(y_test, y_pred_binary))
# Out:
# ----------------
# Confusion matrix
# [[1878  217]
#  [ 285 1751]]
# ----------------
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      2095
#            1       0.89      0.86      0.87      2036
#
#     accuracy                           0.88      4131
#    macro avg       0.88      0.88      0.88      4131
# weighted avg       0.88      0.88      0.88      4131

# %%
def single_vectorize(input_text):
    inp_df = pd.DataFrame([input_text],columns=["text"])
    inp_df["text"]=inp_df["text"].apply(preprocess_text)
    inp_df["text"]=inp_df["text"].apply(tokens_to_vectors)
    return inp_df["text"].to_list()

test_text = """
House Dem Aide: We Didn? Even See Comey? Letter Until Jason Chaffetz Tweeted It By Darrell Lucus on October 30, 2016 Subscribe Jason Chaffetz on the stump in American Fork, Utah ( image courtesy Michael Jolley, available under a Creative Commons-BY license) 
With apologies to Keith Olbermann, there is no doubt who the Worst Person in The World is this week?BI Director James Comey. But according to a House Democratic aide, it looks like we also know who the second-worst person is as well. It turns out that when Comey sent his now-infamous letter announcing that the FBI was looking into emails that may be related to Hillary Clinton? email server, the ranking Democrats on the relevant committees didn? hear about it from Comey. They found out via a tweet from one of the Republican committee chairmen. 
